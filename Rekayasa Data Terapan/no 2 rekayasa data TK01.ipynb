# %%
from pathlib import Path

all_txt_files =[]
for file in Path("D:\Document\S2 FTUI\Semester 2\Rekayasa Data Terapan").rglob("*.txt"):
     all_txt_files.append(file.parent / file.name)
# counts the length of the list
n_files = len(all_txt_files)
print(n_files)
# Out:
# 4

# %%
all_txt_files.sort()
all_txt_files[0]
# Out:
# WindowsPath('D:/Document/S2 FTUI/Semester 2/Rekayasa Data Terapan/test.txt')

# %%
all_docs = []
for txt_file in all_txt_files:
    with open(txt_file) as f:
        txt_file_as_string = f.read()
    all_docs.append(txt_file_as_string)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

tfidf_vectorizer = TfidfVectorizer()
values = tfidf_vectorizer.fit_transform(all_docs)

# Show the Model as a pandas DataFrame
feature_names = tfidf_vectorizer.get_feature_names()
pd.DataFrame(values.toarray(), columns = feature_names)
# Out:
#       after       air     beast   blessed   brought    called   created  \
# 0  0.255888  0.000000  0.255888  0.000000  0.000000  0.255888  0.000000
# 1  0.000000  0.295059  0.000000  0.000000  0.000000  0.000000  0.295059
# 2  0.000000  0.000000  0.000000  0.253874  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.289961  0.000000  0.000000
#
#    creepeth      days   divided  ...      that       the     their      tree  \
# 0  0.255888  0.000000  0.000000  ...  0.201745  0.201745  0.000000  0.000000
# 1  0.000000  0.000000  0.295059  ...  0.000000  0.000000  0.000000  0.295059
# 2  0.000000  0.000000  0.000000  ...  0.200157  0.000000  0.000000  0.000000
# 3  0.000000  0.289961  0.000000  ...  0.000000  0.228609  0.289961  0.000000
#
#        upon      void    waters   wherein    winged       you
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.295059  0.232628
# 2  0.253874  0.253874  0.253874  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.289961  0.000000  0.228609
#
# [4 rows x 49 columns]

# %%
tfIdfVectorizer=TfidfVectorizer(use_idf=True)
tfIdf = tfIdfVectorizer.fit_transform(all_docs)
df = pd.DataFrame(tfIdf[0].T.todense(), index=tfIdfVectorizer.get_feature_names(), columns=["TF-IDF"])
df = df.sort_values('TF-IDF', ascending=False)
print (df.head(100))
# Out:
#              TF-IDF
# after      0.255888
# beast      0.255888
# moved      0.255888
# called     0.255888
# seasons    0.255888
# creepeth   0.255888
# greater    0.255888
# so         0.255888
# don        0.255888
# gathering  0.255888
# stars      0.255888
# fourth     0.255888
# fifth      0.255888
# that       0.201745
# lesser     0.201745
# the        0.201745
# earth      0.163330
# one        0.000000
# their      0.000000
# tree       0.000000
# upon       0.000000
# void       0.000000
# second     0.000000
# waters     0.000000
# seas       0.000000
# saying     0.000000
# wherein    0.000000
# re         0.000000
# winged     0.000000
# over       0.000000
# heaven     0.000000
# night      0.000000
# meat       0.000000
# blessed    0.000000
# brought    0.000000
# created    0.000000
# days       0.000000
# divided    0.000000
# face       0.000000
# female     0.000000
# for        0.000000
# form       0.000000
# from       0.000000
# given      0.000000
# hath       0.000000
# have       0.000000
# air        0.000000
# itself     0.000000
# you        0.000000
